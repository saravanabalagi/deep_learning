# %% [markdown]
# Deep Learning
# =============
#
# Assignment 3
# ------------
#
# Previously in `2_fullyconnected.ipynb`, you trained a logistic regression and a neural network model.
#
# The goal of this assignment is to explore regularization techniques.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 1 to [0.0, 1.0, 0.0 ...], 2 to [0.0, 0.0, 1.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# ---
# Problem 1
# ---------
#
# Introduce and tune L2 regularization for both logistic and neural network models. Remember that L2 amounts to adding a penalty on the norm of the weights to the loss. In TensorFlow, you can compute the L2 loss for a tensor `t` using `nn.l2_loss(t)`. The right amount of regularization should improve your validation / test accuracy.
#
# ---

# %%
num_steps = 3000
batch_size = 125
hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():
    w1 = tf.Variable(tf.truncated_normal([image_size*image_size,hidden_nodes]))
    b1 = tf.Variable(tf.zeros([hidden_nodes]))
    
    w2 = tf.Variable(tf.truncated_normal([hidden_nodes,num_labels]))
    b2 = tf.Variable(tf.zeros([num_labels]))

    x_train = tf.placeholder(tf.float32, shape=(batch_size, image_size*image_size))
    y_train = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    x_valid = tf.constant(valid_dataset)
    y_valid = tf.constant(valid_labels)
    x_test = tf.constant(test_dataset)
    y_test = tf.constant(test_labels)

    logits = tf.matmul(tf.nn.relu(tf.matmul(x_train,w1)+b1),w2)+b2
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_train,logits=logits)) + 0.003*tf.nn.l2_loss(w1) + 0.003*tf.nn.l2_loss(w2)
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    train_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_train,w1)+b1),w2)+b2)
    valid_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_valid,w1)+b1),w2)+b2)
    test_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_test,w1)+b1),w2)+b2)
    
with tf.Session(graph=graph) as session:
    session.run(tf.global_variables_initializer())
    for i in range(num_steps):
        offset = i * batch_size % (train_dataset.shape[0] - batch_size)
        feed_dict = {
            x_train: train_dataset[offset:offset+batch_size], 
            y_train: train_labels[offset:offset+batch_size]
        }
        _,l,predictions = session.run([optimizer,loss,train_predictions], feed_dict=feed_dict)
        if (i+1)%100 == 0:
            print("training loss:", l)
            print("training accuracy: ",accuracy(predictions, train_labels[offset:offset+batch_size]))
            print("valid accuracy: ",accuracy(session.run(valid_predictions), valid_labels))
            print("-" *20)
    print("test accuracy: ",accuracy(session.run(test_predictions), test_labels))
# Out:
# training loss: 715.843
# training accuracy:  84.0
# valid accuracy:  78.4
# --------------------
# training loss: 530.723
# training accuracy:  77.6
# valid accuracy:  78.75
# --------------------
# training loss: 383.219
# training accuracy:  83.2
# valid accuracy:  80.18
# --------------------
# training loss: 290.215
# training accuracy:  74.4
# valid accuracy:  76.42
# --------------------
# training loss: 209.188
# training accuracy:  86.4
# valid accuracy:  80.69
# --------------------
# training loss: 155.631
# training accuracy:  80.8
# valid accuracy:  79.54
# --------------------
# training loss: 114.205
# training accuracy:  80.8
# valid accuracy:  81.81
# --------------------
# training loss: 84.0504
# training accuracy:  83.2
# valid accuracy:  83.3
# --------------------
# training loss: 62.3657
# training accuracy:  82.4
# valid accuracy:  83.38
# --------------------
# training loss: 46.237
# training accuracy:  83.2
# valid accuracy:  84.72
# --------------------
# training loss: 34.2981
# training accuracy:  84.8
# valid accuracy:  84.89
# --------------------
# training loss: 25.5809
# training accuracy:  84.0
# valid accuracy:  85.72
# --------------------
# training loss: 19.092
# training accuracy:  87.2
# valid accuracy:  85.21
# --------------------
# training loss: 14.3055
# training accuracy:  85.6
# valid accuracy:  85.65
# --------------------
# training loss: 10.6793
# training accuracy:  86.4
# valid accuracy:  85.5
# --------------------
# training loss: 7.99113
# training accuracy:  91.2
# valid accuracy:  85.6
# --------------------
# training loss: 6.03953
# training accuracy:  90.4
# valid accuracy:  85.36
# --------------------
# training loss: 4.79828
# training accuracy:  82.4
# valid accuracy:  85.6
# --------------------
# training loss: 3.61669
# training accuracy:  86.4
# valid accuracy:  85.46
# --------------------
# training loss: 2.81632
# training accuracy:  87.2
# valid accuracy:  85.38
# --------------------
# training loss: 2.36115
# training accuracy:  83.2
# valid accuracy:  85.58
# --------------------
# training loss: 1.94676
# training accuracy:  81.6
# valid accuracy:  85.65
# --------------------
# training loss: 1.62985
# training accuracy:  80.0
# valid accuracy:  85.23
# --------------------
# training loss: 1.20635
# training accuracy:  87.2
# valid accuracy:  85.86
# --------------------
# training loss: 1.0831
# training accuracy:  85.6
# valid accuracy:  86.05
# --------------------
# training loss: 1.06142
# training accuracy:  85.6
# valid accuracy:  86.06
# --------------------
# training loss: 0.866556
# training accuracy:  84.0
# valid accuracy:  85.86
# --------------------
# training loss: 0.763754
# training accuracy:  88.8
# valid accuracy:  86.04
# --------------------
# training loss: 0.662796
# training accuracy:  89.6
# valid accuracy:  85.75
# --------------------
# training loss: 0.548287
# training accuracy:  92.0
# valid accuracy:  86.02
# --------------------
# test accuracy:  92.4

# %% [markdown]
# ---
# Problem 2
# ---------
# Let's demonstrate an extreme case of overfitting. Restrict your training data to just a few batches. What happens?
#
# ---

# %%
num_steps = 3000
batch_size = 125
hidden_nodes = 1024

graph = tf.Graph()
with graph.as_default():
    w1 = tf.Variable(tf.truncated_normal([image_size*image_size,hidden_nodes]))
    b1 = tf.Variable(tf.zeros([hidden_nodes]))
    
    w2 = tf.Variable(tf.truncated_normal([hidden_nodes,num_labels]))
    b2 = tf.Variable(tf.zeros([num_labels]))

    x_train = tf.placeholder(tf.float32, shape=(batch_size, image_size*image_size))
    y_train = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    x_valid = tf.constant(valid_dataset)
    y_valid = tf.constant(valid_labels)
    x_test = tf.constant(test_dataset)
    y_test = tf.constant(test_labels)

    logits = tf.matmul(tf.nn.relu(tf.matmul(x_train,w1)+b1),w2)+b2
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_train,logits=logits)) + 0.003*tf.nn.l2_loss(w1) + 0.003*tf.nn.l2_loss(w2)
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    train_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_train,w1)+b1),w2)+b2)
    valid_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_valid,w1)+b1),w2)+b2)
    test_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_test,w1)+b1),w2)+b2)
    
with tf.Session(graph=graph) as session:
    session.run(tf.global_variables_initializer())
    for i in range(num_steps):
        offset = i * batch_size % (batch_size*4- batch_size)
        feed_dict = {
            x_train: train_dataset[offset:offset+batch_size], 
            y_train: train_labels[offset:offset+batch_size]
        }
        _,l,predictions = session.run([optimizer,loss,train_predictions], feed_dict=feed_dict)
        if (i+1)%100 == 0:
            print("training loss:", l)
            print("training accuracy: ",accuracy(predictions, train_labels[offset:offset+batch_size]))
            print("valid accuracy: ",accuracy(session.run(valid_predictions), valid_labels))
            print("-" *20)
    print("test accuracy: ",accuracy(session.run(test_predictions), test_labels))
# Out:
# training loss: 700.767
# training accuracy:  100.0
# valid accuracy:  74.38
# --------------------
# training loss: 519.024
# training accuracy:  100.0
# valid accuracy:  74.46
# --------------------
# training loss: 384.416
# training accuracy:  100.0
# valid accuracy:  74.42
# --------------------
# training loss: 284.718
# training accuracy:  100.0
# valid accuracy:  74.37
# --------------------
# training loss: 210.877
# training accuracy:  100.0
# valid accuracy:  74.36
# --------------------
# training loss: 156.186
# training accuracy:  100.0
# valid accuracy:  74.29
# --------------------
# training loss: 115.68
# training accuracy:  100.0
# valid accuracy:  74.35
# --------------------
# training loss: 85.6785
# training accuracy:  100.0
# valid accuracy:  74.33
# --------------------
# training loss: 63.4585
# training accuracy:  100.0
# valid accuracy:  74.34
# --------------------
# training loss: 47.0017
# training accuracy:  100.0
# valid accuracy:  74.37
# --------------------
# training loss: 34.8139
# training accuracy:  100.0
# valid accuracy:  74.37
# --------------------
# training loss: 25.7892
# training accuracy:  100.0
# valid accuracy:  74.55
# --------------------
# training loss: 19.1074
# training accuracy:  100.0
# valid accuracy:  74.67
# --------------------
# training loss: 14.1631
# training accuracy:  100.0
# valid accuracy:  75.24
# --------------------
# training loss: 10.5056
# training accuracy:  100.0
# valid accuracy:  75.65
# --------------------
# training loss: 7.79983
# training accuracy:  100.0
# valid accuracy:  76.17
# --------------------
# training loss: 5.80199
# training accuracy:  100.0
# valid accuracy:  76.62
# --------------------
# training loss: 4.32314
# training accuracy:  100.0
# valid accuracy:  77.13
# --------------------
# training loss: 3.2298
# training accuracy:  100.0
# valid accuracy:  77.51
# --------------------
# training loss: 2.42431
# training accuracy:  100.0
# valid accuracy:  77.71
# --------------------
# training loss: 1.82544
# training accuracy:  100.0
# valid accuracy:  77.72
# --------------------
# training loss: 1.38237
# training accuracy:  100.0
# valid accuracy:  77.74
# --------------------
# training loss: 1.05739
# training accuracy:  100.0
# valid accuracy:  77.75
# --------------------
# training loss: 0.813446
# training accuracy:  100.0
# valid accuracy:  77.55
# --------------------
# training loss: 0.632665
# training accuracy:  100.0
# valid accuracy:  77.58
# --------------------
# training loss: 0.501361
# training accuracy:  100.0
# valid accuracy:  77.61
# --------------------
# training loss: 0.400923
# training accuracy:  100.0
# valid accuracy:  77.44
# --------------------
# training loss: 0.326288
# training accuracy:  100.0
# valid accuracy:  77.47
# --------------------
# training loss: 0.273444
# training accuracy:  100.0
# valid accuracy:  77.52
# --------------------
# training loss: 0.231311
# training accuracy:  100.0
# valid accuracy:  77.46
# --------------------
# test accuracy:  84.48

# %% [markdown]
# ---
# Problem 3
# ---------
# Introduce Dropout on the hidden layer of the neural network. Remember: Dropout should only be introduced during training, not evaluation, otherwise your evaluation results would be stochastic as well. TensorFlow provides `nn.dropout()` for that, but you have to make sure it's only inserted during training.
#
# What happens to our extreme overfitting case?
#
# ---

# %%
num_steps = 3000
batch_size = 125
hidden_nodes = 1024
dropout = 0.5

graph = tf.Graph()
with graph.as_default():
    w1 = tf.Variable(tf.truncated_normal([image_size*image_size,hidden_nodes]))
    b1 = tf.Variable(tf.zeros([hidden_nodes]))
    
    w2 = tf.Variable(tf.truncated_normal([hidden_nodes,num_labels]))
    b2 = tf.Variable(tf.zeros([num_labels]))

    x_train = tf.placeholder(tf.float32, shape=(batch_size, image_size*image_size))
    y_train = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    x_valid = tf.constant(valid_dataset)
    y_valid = tf.constant(valid_labels)
    x_test = tf.constant(test_dataset)
    y_test = tf.constant(test_labels)

    logits = tf.matmul(tf.nn.dropout(tf.nn.relu(tf.matmul(x_train,w1)+b1),dropout),w2)+b2
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_train,logits=logits)) + 0.003*tf.nn.l2_loss(w1) + 0.003*tf.nn.l2_loss(w2)
    optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)

    train_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_train,w1)+b1),w2)+b2)
    valid_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_valid,w1)+b1),w2)+b2)
    test_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_test,w1)+b1),w2)+b2)
    
with tf.Session(graph=graph) as session:
    session.run(tf.global_variables_initializer())
    for i in range(num_steps):
        offset = i * batch_size % (batch_size*5 - batch_size)
        feed_dict = {
            x_train: train_dataset[offset:offset+batch_size], 
            y_train: train_labels[offset:offset+batch_size]
        }
        _,l,predictions = session.run([optimizer,loss,train_predictions], feed_dict=feed_dict)
        if (i+1)%100 == 0:
            print("training loss:", l)
            print("training accuracy: ",accuracy(predictions, train_labels[offset:offset+batch_size]))
            print("valid accuracy: ",accuracy(session.run(valid_predictions), valid_labels))
            print("-" *20)
    print("test accuracy: ",accuracy(session.run(test_predictions), test_labels))
# Out:
# training loss: 703.426
# training accuracy:  100.0
# valid accuracy:  76.98
# --------------------
# training loss: 521.34
# training accuracy:  100.0
# valid accuracy:  76.81
# --------------------
# training loss: 385.799
# training accuracy:  100.0
# valid accuracy:  77.27
# --------------------
# training loss: 285.774
# training accuracy:  100.0
# valid accuracy:  77.96
# --------------------
# training loss: 211.668
# training accuracy:  100.0
# valid accuracy:  78.06
# --------------------
# training loss: 156.788
# training accuracy:  100.0
# valid accuracy:  78.29
# --------------------
# training loss: 116.155
# training accuracy:  100.0
# valid accuracy:  78.22
# --------------------
# training loss: 86.02
# training accuracy:  100.0
# valid accuracy:  77.76
# --------------------
# training loss: 63.7146
# training accuracy:  100.0
# valid accuracy:  77.84
# --------------------
# training loss: 47.1939
# training accuracy:  100.0
# valid accuracy:  77.8
# --------------------
# training loss: 34.9613
# training accuracy:  100.0
# valid accuracy:  77.81
# --------------------
# training loss: 25.8977
# training accuracy:  100.0
# valid accuracy:  78.04
# --------------------
# training loss: 19.1909
# training accuracy:  100.0
# valid accuracy:  78.13
# --------------------
# training loss: 14.2286
# training accuracy:  100.0
# valid accuracy:  78.4
# --------------------
# training loss: 10.5581
# training accuracy:  100.0
# valid accuracy:  78.56
# --------------------
# training loss: 7.84089
# training accuracy:  100.0
# valid accuracy:  78.74
# --------------------
# training loss: 5.84227
# training accuracy:  100.0
# valid accuracy:  78.85
# --------------------
# training loss: 4.37046
# training accuracy:  100.0
# valid accuracy:  79.06
# --------------------
# training loss: 3.26699
# training accuracy:  100.0
# valid accuracy:  79.25
# --------------------
# training loss: 2.45712
# training accuracy:  100.0
# valid accuracy:  79.26
# --------------------
# training loss: 1.8637
# training accuracy:  100.0
# valid accuracy:  79.23
# --------------------
# training loss: 1.4164
# training accuracy:  100.0
# valid accuracy:  79.33
# --------------------
# training loss: 1.08648
# training accuracy:  100.0
# valid accuracy:  79.26
# --------------------
# training loss: 0.842573
# training accuracy:  100.0
# valid accuracy:  79.26
# --------------------
# training loss: 0.661424
# training accuracy:  100.0
# valid accuracy:  79.21
# --------------------
# training loss: 0.529132
# training accuracy:  100.0
# valid accuracy:  79.31
# --------------------
# training loss: 0.430231
# training accuracy:  100.0
# valid accuracy:  79.46
# --------------------
# training loss: 0.357443
# training accuracy:  100.0
# valid accuracy:  79.25
# --------------------
# training loss: 0.302428
# training accuracy:  100.0
# valid accuracy:  79.36
# --------------------
# training loss: 0.254662
# training accuracy:  100.0
# valid accuracy:  79.4
# --------------------
# test accuracy:  86.58

# %% [markdown]
# ---
# Problem 4
# ---------
#
# Try to get the best performance you can using a multi-layer model! The best reported test accuracy using a deep network is [97.1%](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html?showComment=1391023266211#c8758720086795711595).
#
# One avenue you can explore is to add multiple layers.
#
# Another one is to use learning rate decay:
#
#     global_step = tf.Variable(0)  # count the number of steps taken.
#     learning_rate = tf.train.exponential_decay(0.5, global_step, ...)
#     optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=global_step)
#
#  ---

# %%
num_steps = 3000
batch_size = 500
hidden_nodes = 1024
regularization_constant = 0.003
dropout_ratio = 1
starter_learning_rate = 0.3


graph = tf.Graph()
with graph.as_default():
    w1 = tf.Variable(tf.truncated_normal([image_size*image_size,hidden_nodes]))
    b1 = tf.Variable(tf.zeros([hidden_nodes]))
    
    w2 = tf.Variable(tf.truncated_normal([hidden_nodes,num_labels]))
    b2 = tf.Variable(tf.zeros([num_labels]))

    x_train = tf.placeholder(tf.float32, shape=(batch_size, image_size*image_size))
    y_train = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    x_valid = tf.constant(valid_dataset)
    y_valid = tf.constant(valid_labels)
    x_test = tf.constant(test_dataset)
    y_test = tf.constant(test_labels)
    
    h1 = tf.nn.relu(tf.matmul(x_train,w1)+b1)
    logits = tf.matmul(tf.nn.dropout(h1,dropout_ratio),w2)+b2
    
    global_step = tf.Variable(0, trainable=False)
    learning_rate = tf.train.exponential_decay(starter_learning_rate, global_step, 1000, 0.96, staircase=True)

    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_train,logits=logits)) 
    loss +=  regularization_constant * (tf.nn.l2_loss(w1) + tf.nn.l2_loss(w2))
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    train_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_train,w1)+b1),w2)+b2)
    valid_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_valid,w1)+b1),w2)+b2)
    test_predictions = tf.nn.softmax(tf.matmul(tf.nn.relu(tf.matmul(x_test,w1)+b1),w2)+b2)
    
with tf.Session(graph=graph) as session:
    session.run(tf.global_variables_initializer())
    for i in range(num_steps):
        offset = i * batch_size % (train_dataset.shape[0] - batch_size)
        feed_dict = {
            x_train: train_dataset[offset:offset+batch_size], 
            y_train: train_labels[offset:offset+batch_size]
        }
        _,l,predictions = session.run([optimizer,loss,train_predictions], feed_dict=feed_dict)
        if (i+1)%100 == 0:
            print("training loss:", l)
            print("minibatch accuracy: ",accuracy(predictions, train_labels[offset:offset+batch_size]))
            print("valid accuracy: ",accuracy(session.run(valid_predictions), valid_labels))
            print("-" *20)
    print("test accuracy: ",accuracy(session.run(test_predictions), test_labels))
# Out:
# training loss: 803.719
# minibatch accuracy:  77.8
# valid accuracy:  79.28
# --------------------
# training loss: 665.435
# minibatch accuracy:  80.8
# valid accuracy:  80.36
# --------------------
# training loss: 565.969
# minibatch accuracy:  72.0
# valid accuracy:  74.87
# --------------------
# training loss: 456.154
# minibatch accuracy:  86.0
# valid accuracy:  82.72
# --------------------
# training loss: 380.758
# minibatch accuracy:  84.2
# valid accuracy:  83.15
# --------------------
# training loss: 317.974
# minibatch accuracy:  85.8
# valid accuracy:  82.72
# --------------------
# training loss: 264.713
# minibatch accuracy:  85.8
# valid accuracy:  83.68
# --------------------
# training loss: 220.341
# minibatch accuracy:  86.4
# valid accuracy:  83.81
# --------------------
# training loss: 184.239
# minibatch accuracy:  84.6
# valid accuracy:  84.27
# --------------------
# training loss: 153.807
# minibatch accuracy:  83.6
# valid accuracy:  81.03
# --------------------
# training loss: 128.153
# minibatch accuracy:  86.4
# valid accuracy:  84.29
# --------------------
# training loss: 106.932
# minibatch accuracy:  87.6
# valid accuracy:  84.82
# --------------------
# training loss: 89.2338
# minibatch accuracy:  87.8
# valid accuracy:  84.95
# --------------------
# training loss: 74.6092
# minibatch accuracy:  88.2
# valid accuracy:  85.12
# --------------------
# training loss: 62.3709
# minibatch accuracy:  85.4
# valid accuracy:  85.58
# --------------------
# training loss: 52.0453
# minibatch accuracy:  89.4
# valid accuracy:  85.99
# --------------------
# training loss: 43.6523
# minibatch accuracy:  86.0
# valid accuracy:  86.36
# --------------------
# training loss: 36.5288
# minibatch accuracy:  87.4
# valid accuracy:  86.65
# --------------------
# training loss: 30.4958
# minibatch accuracy:  90.0
# valid accuracy:  86.83
# --------------------
# training loss: 25.606
# minibatch accuracy:  89.0
# valid accuracy:  87.16
# --------------------
# training loss: 21.4414
# minibatch accuracy:  89.6
# valid accuracy:  87.33
# --------------------
# training loss: 17.9953
# minibatch accuracy:  89.0
# valid accuracy:  86.98
# --------------------
# training loss: 15.1686
# minibatch accuracy:  88.0
# valid accuracy:  87.23
# --------------------
# training loss: 12.7167
# minibatch accuracy:  89.6
# valid accuracy:  87.54
# --------------------
# training loss: 10.6845
# minibatch accuracy:  89.2
# valid accuracy:  87.62
# --------------------
# training loss: 9.01777
# minibatch accuracy:  89.4
# valid accuracy:  87.36
# --------------------
# training loss: 7.66488
# minibatch accuracy:  88.6
# valid accuracy:  87.55
# --------------------
# training loss: 6.44226
# minibatch accuracy:  89.8
# valid accuracy:  87.61
# --------------------
# training loss: 5.47067
# minibatch accuracy:  90.6
# valid accuracy:  87.49
# --------------------
# training loss: 4.67839
# minibatch accuracy:  89.2
# valid accuracy:  87.52
# --------------------
# test accuracy:  93.89
